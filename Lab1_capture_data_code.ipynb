# %%
import ugradio
import numpy as np
import matplotlib.pyplot as plt

# %%
# is the divisor the number you divide the frequency by???
# what does nblocks do?
data = ugradio.pico.capture_data('1V', divisor=4, dual_mode=True, nblocks = 3)

# %%
data[0,0,:100]
plt.plot(data[0,0,:100])

# %%
np.savez('data1.npz', data)

# %%
data = np.load('data.npz')['arr_0']

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(data[0,0,:100])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dataa = ugradio.pico.capture_data('1V', divisor=1, dual_mode=True, nblocks = 3)

# %%
np.savez('data1a.npz', dataa)

# %%
#hehehe
