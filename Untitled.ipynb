# %%
import ugradio
import numpy as np
import matplotlib.pyplot as plt

# %%
data = ugradio.pico.capture_data('1V', divisor=1, dual_mode=True, nblocks = 3)

# %%
data[0,0,:100]
plt.plot(data[0,0,:100])
