# %%
import numpy as np
import matplotlib.pyplot as plt
import ugradio

# %% [markdown]
# # 5.2

# %%
data1 = 'data.npz'
npz = np.load('data.npz')
npz.files
data1 = npz['arr_0']
print(data1)
signal_A = npz['arr_0'][0,0,:100]
signal_B = npz['arr_0'][1,0,:100]
#plt.plot(data1[0,0,:100])
# Out:
# [[[ -9216  11008 -12544 ...  -6912   4864  -2560]
#   [-17152  17408 -17152 ...   7680  -9472  11264]
#   [-14848  13824 -12288 ...  15616 -16384  16896]]
#
#  [[ 16640   3584 -10496 ...  -5632   8960  19712]
#   [-20480 -15104  -2304 ...  15872   2304 -11520]
#   [ 19968   9728  -4864 ... -11264   2816  15872]]]

# %%
fig = plt.figure()
plt.title('Sampled Data at 62.5 MHz')
#put x axis in time units
plt.xlabel('time (mmmmsec)') #62500 data points per second. 100 data points = .0016 seconds whole length
#what is the units of the voltage? maybe change so units are smaller??/ makes more sense
plt.ylabel('voltage (mV)') #millivolts?
plt.plot(data1[0,0,:100])
fig.savefig('sample_data_plot.pdf')

# %%
signal_A = npz['arr_0'][0,0,:100]
signal_B = npz['arr_0'][1,0,:100]
plt.xlim(0,100)
plt.ylim(-40000,40000)
plt.xlabel('Number of samples')
plt.ylabel('Volts (V/(2**16))')
plt.title('Signal A and B Sampled at 62.5 MHz')
plt.plot(signal_A)
plt.plot(signal_B)
fig.savefig('signals_A_B_plot.pdf')

# %%
'Sampling interval = 1/sampling frequncy'
' # of samples = 100'
' sampling frequency = 62.5 MHz = 62500 Hz = '

# %% [markdown]
# Does the period match like you expected??

# %% [markdown]
# Caption for plot: stand-alone description of the plot and what it demonstrates

# %% [markdown]
# *What is the minimal sampling rate that accuratley reproduces the spectral frequency nu_knot in the sampled data??
# -that is Nyquist's Critereon

# %%
ffty = np.fft.fft(data1[0,0,:100])
#print(ffty)
# Out:
# [ 4.60800000e+03+0.00000000e+00j  0.00000000e+00-9.59392331e+01j
#  -4.76045561e+02+0.00000000e+00j  0.00000000e+00-2.74343319e+02j
#  -6.53720859e+02-5.96069301e+02j  2.84217094e-14-4.14216701e+02j
#  -2.17998997e+02+2.84217094e-14j  7.10542736e-15-4.95914578e+02j
#  -3.24557494e+02+3.53461458e+02j -1.42108547e-14-5.07962727e+02j
#   1.58216701e+02+0.00000000e+00j -1.42108547e-14-4.48669020e+02j
#  -4.64344181e+02-2.03018606e+02j  0.00000000e+00-3.26361083e+02j
#   4.48669020e+02+1.42108547e-14j  2.84217094e-14-1.58216701e+02j
#   4.52523147e+02-2.90624458e+02j  0.00000000e+00+3.21487460e+01j
#   4.95914578e+02+1.42108547e-14j  0.00000000e+00+2.17998997e+02j
#   4.14216701e+02+0.00000000e+00j  0.00000000e+00+3.73231937e+02j
#   2.74343319e+02+0.00000000e+00j  0.00000000e+00+4.76045561e+02j
#   5.77578442e+02+2.64783396e+02j -2.29936459e-14+5.12000000e+02j
#  -9.59392331e+01-4.80524384e-14j -5.74841148e-15+4.76045561e+02j
#  -3.30188266e+02+8.87630018e+02j  1.14968230e-14+3.73231937e+02j
#  -4.14216701e+02+1.67058616e-14j  1.14968230e-14+2.17998997e+02j
#  -1.69351791e+02-1.29295354e+02j  0.00000000e+00+3.21487460e+01j
#  -5.07962727e+02-2.82026846e-14j -1.46407151e-14-1.58216701e+02j
#   1.01157981e+03+1.37126492e+03j  1.25293962e-14-3.26361083e+02j
#  -3.26361083e+02+5.20903868e-15j  3.34117233e-14-4.48669020e+02j
#  -1.58216701e+02+0.00000000e+00j  0.00000000e+00-5.07962727e+02j
#   3.21487460e+01+0.00000000e+00j  0.00000000e+00-4.95914578e+02j
#  -1.23243263e+03+1.83232126e+02j  8.78279122e-15-4.14216701e+02j
#   3.73231937e+02+4.93287692e-14j  2.19569781e-15-2.74343319e+02j
#  -4.62227086e+05-7.29103470e+05j -4.39139561e-15-9.59392331e+01j
#   5.12000000e+02-2.70306520e-14j -4.39139561e-15+9.59392331e+01j
#  -4.62227086e+05+7.29103470e+05j  0.00000000e+00+2.74343319e+02j
#   3.73231937e+02+3.14220476e-14j -4.73253476e-15+4.14216701e+02j
#  -1.23243263e+03-1.83232126e+02j -2.02729890e-14+4.95914578e+02j
#   3.21487460e+01-2.26392563e-14j -5.40613039e-14+5.07962727e+02j
#  -1.58216701e+02+0.00000000e+00j  0.00000000e+00+4.48669020e+02j
#  -3.26361083e+02+0.00000000e+00j  0.00000000e+00+3.26361083e+02j
#   1.01157981e+03-1.37126492e+03j  8.78279122e-15+1.58216701e+02j
#  -5.07962727e+02-3.17631867e-14j  2.19569781e-15-3.21487460e+01j
#  -1.69351791e+02+1.29295354e+02j -4.39139561e-15-2.17998997e+02j
#  -4.14216701e+02+2.70306520e-14j -4.39139561e-15-3.73231937e+02j
#  -3.30188266e+02-8.87630018e+02j  0.00000000e+00-4.76045561e+02j
#  -9.59392331e+01-2.26392563e-14j  2.22981172e-14-5.12000000e+02j
#   5.77578442e+02-2.64783396e+02j  2.02729890e-14-4.76045561e+02j
#   2.74343319e+02+3.14220476e-14j  5.40613039e-14-3.73231937e+02j
#   4.14216701e+02+0.00000000e+00j  0.00000000e+00-2.17998997e+02j
#   4.95914578e+02+0.00000000e+00j  0.00000000e+00-3.21487460e+01j
#   4.52523147e+02+2.90624458e+02j -2.29936459e-14+1.58216701e+02j
#   4.48669020e+02+2.06514653e-15j -5.74841148e-15+3.26361083e+02j
#  -4.64344181e+02+2.03018606e+02j  1.14968230e-14+4.48669020e+02j
#   1.58216701e+02-1.67058616e-14j  1.14968230e-14+5.07962727e+02j
#  -3.24557494e+02-3.53461458e+02j  0.00000000e+00+4.95914578e+02j
#  -2.17998997e+02+5.20903868e-15j -3.13465768e-14+4.14216701e+02j
#  -6.53720859e+02+5.96069301e+02j -1.25293962e-14+2.74343319e+02j
#  -4.76045561e+02-2.82026846e-14j -3.34117233e-14+9.59392331e+01j]

# %%
np.shape(ffty)
np.fft.fftfreq(1,ffty)
# Out:
# array([ 0.+0.j, -0.+0.j,  0.-0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.-0.j,
#         0.+0.j,  0.-0.j, -0.+0.j,  0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,
#         0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#         0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  0.-0.j, -0.+0.j,  0.-0.j,
#         0.-0.j,  0.+0.j,  0.-0.j,  0.+0.j, -0.+0.j,  0.+0.j, -0.+0.j,
#        -0.+0.j,  0.+0.j,  0.+0.j,  0.-0.j,  0.+0.j,  0.-0.j, -0.+0.j,
#         0.+0.j, -0.+0.j,  0.-0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#        -0.+0.j,  0.+0.j,  0.-0.j,  0.-0.j,  0.+0.j,  0.+0.j,  0.-0.j,
#        -0.+0.j,  0.-0.j,  0.+0.j,  0.-0.j,  0.-0.j,  0.+0.j,  0.-0.j,
#         0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,  0.+0.j,  0.-0.j, -0.+0.j,
#         0.-0.j, -0.+0.j, -0.+0.j, -0.+0.j, -0.+0.j,  0.+0.j,  0.+0.j,
#         0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.+0.j,  0.+0.j, -0.+0.j,
#         0.+0.j,  0.-0.j,  0.+0.j,  0.-0.j,  0.-0.j,  0.+0.j,  0.+0.j,
#         0.+0.j, -0.+0.j,  0.+0.j,  0.-0.j,  0.-0.j,  0.-0.j,  0.-0.j,
#        -0.+0.j,  0.-0.j])

# %%
#plt.plot(ffty)

# %% [markdown]
# # 5.3

# %%
#To plot the imaginary part of the plot and real part of the plot
ffty.imag
plt.plot(ffty.imag) #blue
plt.plot(ffty.real) #orange
plt.title('Fourier transform of real and imaginary voltages?')
plt.legend(['imaginary', 'real'])
plt.xlabel('time (sec)')
plt.ylabel('Voltage (Hz??)')
fig.savefig('voltage_plot.pdf')
#Caption:

# %% [markdown]
# ???: Do the plotted points exhibit any symmetry between negative and positive frequencies?
# -- Yes the plots of imaginary component and real component both have a trough at time=47, although each has a different amplitude. But where the plot of the imaginary component peaks is where the plot of the real component has a min, at time=53, and still different amplitudes; the real is negative while the imaginary is positive.

# %% [raw]
# --7-- and answer questions

# %%
# How to find POWER SPECTRUM?
# use dft to find power spectrum?
#do inverse ft on power spectrum using dft.idft
# ugradio.dft

# Indepdent Data streams
x = np.linspace(-10,10,100)
y = np.sin(x)
#plt.plot(y)
fft_fluke = np.fft.fft(y)
fft_fluke[-1]
plt.plot(fft_fluke.imag) #blue
plt.plot(fft_fluke.real) #orange
plt.title('Fourier transform of real and imaginary voltages?')
plt.legend(['imaginary', 'real'])
plt.xlabel('time (sec)')
plt.ylabel('Voltage (Hz??)')
#fig.savefig('fluke_voltage_plot.pdf')
#Caption:

#compare plots for several independent data captures of the same sine wave:
# Out:
# Text(0, 0.5, 'Voltage (Hz??)')

# %%
power = np.abs(ffty)**2
# power = voltage x current --> what are the units??
# power is proportional to the power squared

# %%
#print(power)
plt.plot(power)
plt.title('Power')
plt.xlabel('time (sec)')
plt.ylabel('???')
#fig.savefig('power_plot.pdf')

'The plot for power and voltage peak at the same x-points'
'repeatability?'
'what king of symmetry do the two plots have'
# Out:
# Text(0, 0.5, '???')

# %%
x = ugradio.dft.idft(power) #first array is the input
x[1]
y = ugradio.dft.dft(power)
y[1]

y[1]/x[1]
# np.correlate()
# scipy.signal.correlate()
# Separately calculate the ACF... ~Correlation thm~
# Out:
# array([ 100.-1.04527879e-18j, -100.-1.01265172e-15j,
#         100.-2.10169413e-15j, -100.-1.52260838e-18j,
#         100.+9.36001284e-15j, -100.+5.05807502e-15j,
#         100.-5.57795631e-15j, -100.+1.91461337e-17j,
#         100.-1.70928631e-17j, -100.-5.76412587e-14j,
#         100.+2.65576193e-14j, -100.-4.36326116e-14j,
#         100.+2.41741483e-16j, -100.-6.37389120e-17j,
#         100.-4.37423651e-14j, -100.+2.64993296e-14j,
#         100.-5.76907894e-14j, -100.-9.13289555e-18j,
#         100.-1.22822448e-17j, -100.-5.62853134e-15j,
#         100.+5.03482494e-15j, -100.+9.34014684e-15j,
#         100.+1.70637146e-18j, -100.-2.11945960e-15j,
#         100.-1.02844633e-15j, -100.+9.72877859e-19j,
#         100.+1.03272711e-15j, -100.+2.09942620e-15j,
#         100.-2.08964874e-17j, -100.-9.33844086e-15j,
#         100.-5.05879156e-15j, -100.+5.60532817e-15j,
#         100.-3.59947313e-18j, -100.+1.44395406e-17j,
#         100.+5.76895282e-14j, -100.-2.65586856e-14j,
#         100.+4.36875209e-14j, -100.+7.69530767e-17j,
#         100.+7.30665577e-17j, -100.+4.37424954e-14j,
#         100.-2.65297382e-14j, -100.+5.77028282e-14j,
#         100.+1.12851615e-17j, -100.+4.47062221e-18j,
#         100.+5.61716413e-15j, -100.-5.05326284e-15j,
#         100.-9.33953408e-15j, -100.-6.19544099e-18j,
#         100.+2.10930430e-15j, -100.+1.03572858e-15j,
#         100.+0.00000000e+00j, -100.-1.03572858e-15j,
#         100.-2.10930430e-15j, -100.+6.19544099e-18j,
#         100.+9.33953408e-15j, -100.+5.05326284e-15j,
#         100.-5.61716413e-15j, -100.-4.47062221e-18j,
#         100.-1.12851615e-17j, -100.-5.77028282e-14j,
#         100.+2.65297382e-14j, -100.-4.37424954e-14j,
#         100.-7.30665577e-17j, -100.-7.69530767e-17j,
#         100.-4.36875209e-14j, -100.+2.65586856e-14j,
#         100.-5.76895282e-14j, -100.-1.44395406e-17j,
#         100.+3.59947313e-18j, -100.-5.60532817e-15j,
#         100.+5.05879156e-15j, -100.+9.33844086e-15j,
#         100.+2.08964874e-17j, -100.-2.09942620e-15j,
#         100.-1.03272711e-15j, -100.-9.72877859e-19j,
#         100.+1.02844633e-15j, -100.+2.11945960e-15j,
#         100.-1.70637146e-18j, -100.-9.34014684e-15j,
#         100.-5.03482494e-15j, -100.+5.62853134e-15j,
#         100.+1.22822448e-17j, -100.+9.13289555e-18j,
#         100.+5.76907894e-14j, -100.-2.64993296e-14j,
#         100.+4.37423651e-14j, -100.+6.37389120e-17j,
#         100.-2.41741483e-16j, -100.+4.36326116e-14j,
#         100.-2.65576193e-14j, -100.+5.76412587e-14j,
#         100.+1.70928631e-17j, -100.-1.91461337e-17j,
#         100.+5.57795631e-15j, -100.-5.05807502e-15j,
#         100.-9.36001284e-15j, -100.+1.52260838e-18j,
#         100.+2.10169413e-15j, -100.+1.01265172e-15j])

# %% [markdown]
# # 5.4
